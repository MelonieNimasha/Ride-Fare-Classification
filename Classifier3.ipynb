# %%
 from pathlib import Path
import pandas as pd
import numpy as np
 
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score 

np.random.seed(0)

# %%
joined_df = pd.read_csv('train.csv' , index_col= 'tripid')
print('joined_df.shape : ', joined_df.shape)
# Out:
# joined_df.shape :  (17176, 13)

# %%
joined_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51
#
#            pick_lat  pick_lon  drop_lat  drop_lon    fare    label
# tripid
# 189123628   6.86252   79.8993   6.90330   79.8783  270.32  correct
# 189125358   6.88589   79.8984   6.91373   79.8923  197.85  correct
# 189125719   6.90839   79.8651   6.93669   79.9146  301.64  correct
# 189127273   6.92570   79.8895   6.92748   79.8971   82.30  correct
# 189128020   6.87441   79.8615   6.84478   79.9290  358.39  correct

# %%
joined_df['label'] = joined_df['label'].map( {'correct':True, 'incorrect':False} )
joined_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51
#
#            pick_lat  pick_lon  drop_lat  drop_lon    fare  label
# tripid
# 189123628   6.86252   79.8993   6.90330   79.8783  270.32   True
# 189125358   6.88589   79.8984   6.91373   79.8923  197.85   True
# 189125719   6.90839   79.8651   6.93669   79.9146  301.64   True
# 189127273   6.92570   79.8895   6.92748   79.8971   82.30   True
# 189128020   6.87441   79.8615   6.84478   79.9290  358.39   True

# %%
features_df = joined_df.drop(['label'], axis = 1)
features_df = features_df.drop(['pickup_time'], axis = 1)
features_df = features_df.drop(['drop_time'], axis = 1)

# %%
features_df["distance"]=((features_df["pick_lat"]-features_df["drop_lat"])**2)+((features_df["pick_lon"]-features_df["drop_lon"])**2)

# %%
features_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup  pick_lat  pick_lon  drop_lat  drop_lon  \
# tripid
# 189123628                       64.0   6.86252   79.8993   6.90330   79.8783
# 189125358                      134.0   6.88589   79.8984   6.91373   79.8923
# 189125719                       61.0   6.90839   79.8651   6.93669   79.9146
# 189127273                       68.0   6.92570   79.8895   6.92748   79.8971
# 189128020                        NaN   6.87441   79.8615   6.84478   79.9290
#
#              fare  distance
# tripid
# 189123628  270.32  0.002104
# 189125358  197.85  0.000812
# 189125719  301.64  0.003251
# 189127273   82.30  0.000061
# 189128020  358.39  0.005434

# %%
features_df = features_df.drop(['pick_lat'], axis = 1)
features_df = features_df.drop(['drop_lat'], axis = 1)
features_df = features_df.drop(['pick_lon'], axis = 1)
features_df = features_df.drop(['drop_lon'], axis = 1)

# %%
features_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup    fare  distance
# tripid
# 189123628                       64.0  270.32  0.002104
# 189125358                      134.0  197.85  0.000812
# 189125719                       61.0  301.64  0.003251
# 189127273                       68.0   82.30  0.000061
# 189128020                        NaN  358.39  0.005434

# %%
labels=joined_df.drop(['additional_fare'], axis = 1)
labels=labels.drop(['duration'], axis = 1)
labels=labels.drop(['meter_waiting'], axis = 1)
labels=labels.drop(['meter_waiting_fare'], axis = 1)
labels=labels.drop(['meter_waiting_till_pickup'], axis = 1)
labels=labels.drop(['pick_lat'], axis = 1)
labels=labels.drop(['pick_lon'], axis = 1)
labels=labels.drop(['drop_lat'], axis = 1)
labels=labels.drop(['drop_lon'], axis = 1)
labels=labels.drop(['fare'], axis = 1)
labels=labels.drop(['pickup_time'], axis = 1)
labels=labels.drop(['drop_time'], axis = 1)

# %%
labels.head()
# Out:
#            label
# tripid
# 189123628   True
# 189125358   True
# 189125719   True
# 189127273   True
# 189128020   True

# %%
numeric_features = ['additional_fare', 'duration', 'meter_waiting', 'meter_waiting_fare', 'meter_waiting_till_pickup','distance' , 'fare']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features)])

# %%
RANDOM_SEED=0
X_train, X_eval, y_train, y_eval = train_test_split(
    features_df,
    labels,
    test_size=0.1,
    shuffle=True,
    stratify=labels,
    random_state=RANDOM_SEED
)

# %%
X_train.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 195426968             10.5     435.0          101.0              0.0000
# 207461765             10.5     742.0          294.0             17.1402
# 212629700             10.5    2353.0          520.0             30.0560
# 198439131             10.5    1520.0          490.0              9.0746
# 205426320             10.5    4619.0          971.0             56.1238
#
#            meter_waiting_till_pickup    fare      distance
# tripid
# 195426968                       10.0  397.96  1.420201e-04
# 207461765                        6.0  121.32  1.622601e-04
# 212629700                       22.0  486.04  1.010000e-08
# 198439131                      211.0  221.46  1.765330e-03
# 205426320                      163.0  804.21  1.778490e-03

# %%
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', LogisticRegression())])

# %%
clf.fit(X_train, y_train)
print("model score: %.3f" % clf.score(X_train, y_train))
# Out:
# model score: 0.909

# %%
val_pred = clf.predict_proba(X_eval)
val_pred
# Out:
# array([[0.06472681, 0.93527319],
#        [0.06882696, 0.93117304],
#        [0.09188537, 0.90811463],
#        ...,
#        [0.09805344, 0.90194656],
#        [0.05969608, 0.94030392],
#        [0.08706466, 0.91293534]])

# %%
t=0.7
val_pred = val_pred > t
val_pred.astype(np.int)
y_pred=pd.DataFrame(val_pred[:,1])
y_pred
# Out:
#          0
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# ...    ...
# 1713  True
# 1714  True
# 1715  True
# 1716  True
# 1717  True
#
# [1718 rows x 1 columns]

# %%
f1_score(y_eval, y_pred, average='micro')
# Out:
# 0.9109429569266589

# %%
test_df = pd.read_csv('test.csv' , index_col= 'tripid')
test_df = test_df.drop(['pickup_time'], axis = 1)
test_df = test_df.drop(['drop_time'], axis = 1)
test_df
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 213284604             10.5       924             42             2.44860
# 213286352             10.5      4249             20             0.00000
# 213293973             10.5      1552            255             2.65880
# 213294622             10.5       462             16             0.00000
# 213298687             10.5       814            392            12.36920
# ...                    ...       ...            ...                 ...
# 222856243             10.5      1723            429            24.83332
# 222857785             10.5      1378             80             0.00000
# 222858416             10.5       418             56             3.28440
# 222858691             10.5      1604            548            31.67440
# 222860703             10.5      1698            691            32.88820
#
#            meter_waiting_till_pickup  pick_lat  pick_lon  drop_lat  drop_lon  \
# tripid
# 213284604                        148   6.83454   79.8750   6.77490   79.8840
# 213286352                         91   6.91168   79.8723   6.55091   79.9706
# 213293973                         23   6.92145   79.8478   6.90539   79.8989
# 213294622                        198   6.77433   79.9416   6.80401   79.9407
# 213298687                         69   6.97968   79.9130   6.98875   79.8914
# ...                              ...       ...       ...       ...       ...
# 222856243                          3   6.85103   79.9567   6.85588   79.9214
# 222857785                        125   6.91293   79.9656   6.92112   79.8980
# 222858416                         93   6.85718   79.9081   6.83868   79.9083
# 222858691                         17   6.91289   79.8846   6.93159   79.9145
# 222860703                         42   6.91682   79.9192   6.87020   79.9340
#
#               fare
# tripid
# 213284604   289.27
# 213286352  1912.70
# 213293973   394.00
# 213294622   154.32
# 213298687   147.47
# ...            ...
# 222856243   388.48
# 222857785   379.85
# 222858416   112.79
# 222858691   248.46
# 222860703   339.63
#
# [8576 rows x 10 columns]

# %%
test_df["distance"]=((test_df["pick_lat"]-test_df["drop_lat"])**2)+((test_df["pick_lon"]-test_df["drop_lon"])**2)

# %%
test_df = test_df.drop(['pick_lat'], axis = 1)
test_df = test_df.drop(['drop_lat'], axis = 1)
test_df = test_df.drop(['pick_lon'], axis = 1)
test_df = test_df.drop(['drop_lon'], axis = 1)

# %%
test_probas = clf.predict_proba(test_df)
result = test_probas > t
result.astype(np.int)
result
# Out:
# array([[False,  True],
#        [False,  True],
#        [False,  True],
#        ...,
#        [False,  True],
#        [False,  True],
#        [False,  True]])

# %%
submission_df = pd.read_csv("sample_submission.csv", 
                            index_col="tripid")

# %%
np.testing.assert_array_equal(test_df.index.values, 
                              submission_df.index.values)

# %%
submission_df["prediction"] = result[:, 1]

# %%
submission_df.head()
# Out:
#            prediction
# tripid
# 213284604        True
# 213286352        True
# 213293973        True
# 213294622        True
# 213298687        True

# %%
submission_df.to_csv('results3.csv', index=True)
