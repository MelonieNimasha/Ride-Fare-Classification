# %%
from pathlib import Path
import pandas as pd
import numpy as np
 
# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

from sklearn.compose import ColumnTransformer
from sklearn.datasets import fetch_openml
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn import svm
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score 

np.random.seed(0)

# %%
joined_df = pd.read_csv('train.csv' , index_col= 'tripid')
print('joined_df.shape : ', joined_df.shape)
# Out:
# joined_df.shape :  (17176, 13)

# %%
joined_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51
#
#            pick_lat  pick_lon  drop_lat  drop_lon    fare    label
# tripid
# 189123628   6.86252   79.8993   6.90330   79.8783  270.32  correct
# 189125358   6.88589   79.8984   6.91373   79.8923  197.85  correct
# 189125719   6.90839   79.8651   6.93669   79.9146  301.64  correct
# 189127273   6.92570   79.8895   6.92748   79.8971   82.30  correct
# 189128020   6.87441   79.8615   6.84478   79.9290  358.39  correct

# %%
joined_df['label'] = joined_df['label'].map( {'correct':True, 'incorrect':False} )
joined_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51
#
#            pick_lat  pick_lon  drop_lat  drop_lon    fare  label
# tripid
# 189123628   6.86252   79.8993   6.90330   79.8783  270.32   True
# 189125358   6.88589   79.8984   6.91373   79.8923  197.85   True
# 189125719   6.90839   79.8651   6.93669   79.9146  301.64   True
# 189127273   6.92570   79.8895   6.92748   79.8971   82.30   True
# 189128020   6.87441   79.8615   6.84478   79.9290  358.39   True

# %%
def distance(lat1, lon1, lat2, lon2):
    p = 0.017453292519943295 # Pi/180
    a = 0.5 - np.cos((lat2 - lat1) * p)/2 + np.cos(lat1 * p) * np.cos(lat2 * p) * (1 - np.cos((lon2 - lon1) * p)) / 2
    return 0.6213712 * 12742 * np.arcsin(np.sqrt(a))

# %%
features_df = joined_df.drop(['label'], axis = 1)

# %%
features_df["distance"] =  distance(features_df["pick_lat"],features_df["pick_lon"],features_df["drop_lat"],features_df["drop_lon"])

# %%
features_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51
#
#            pick_lat  pick_lon  drop_lat  drop_lon    fare  distance
# tripid
# 189123628   6.86252   79.8993   6.90330   79.8783  270.32  3.164501
# 189125358   6.88589   79.8984   6.91373   79.8923  197.85  1.968540
# 189125719   6.90839   79.8651   6.93669   79.9146  301.64  3.917991
# 189127273   6.92570   79.8895   6.92748   79.8971   82.30  0.535588
# 189128020   6.87441   79.8615   6.84478   79.9290  358.39  5.062797

# %%
features_df = features_df.drop(['pick_lat'], axis = 1)
features_df = features_df.drop(['drop_lat'], axis = 1)
features_df = features_df.drop(['pick_lon'], axis = 1)
features_df = features_df.drop(['drop_lon'], axis = 1)

# %%
features_df.head()
# Out:
#            additional_fare  duration  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5     834.0           56.0              0.0000
# 189125358             10.5     791.0           47.0              0.0000
# 189125719             10.5    1087.0           80.0              0.0000
# 189127273             10.5     598.0          271.0             15.6638
# 189128020              NaN       NaN            NaN                 NaN
#
#            meter_waiting_till_pickup     pickup_time       drop_time    fare  \
# tripid
# 189123628                       64.0  11/1/2019 0:20  11/1/2019 0:34  270.32
# 189125358                      134.0  11/1/2019 0:56  11/1/2019 1:09  197.85
# 189125719                       61.0  11/1/2019 1:08  11/1/2019 1:26  301.64
# 189127273                       68.0  11/1/2019 2:27  11/1/2019 2:37   82.30
# 189128020                        NaN  11/1/2019 3:34  11/1/2019 3:51  358.39
#
#            distance
# tripid
# 189123628  3.164501
# 189125358  1.968540
# 189125719  3.917991
# 189127273  0.535588
# 189128020  5.062797

# %%
features_df["pickup_time"] = pd.to_datetime(features_df["pickup_time"],errors = "coerce")

# %%
features_df["drop_time"] = pd.to_datetime(features_df["drop_time"],errors = "coerce")

# %%
features_df["pickup_time_hour"] = features_df["pickup_time"].dt.hour

# %%
features_df["pickup_time_minute"] = features_df["pickup_time"].dt.minute

# %%
features_df["drop_time_hour"] =features_df["drop_time"].dt.hour
features_df["drop_time_minute"] =features_df["drop_time"].dt.minute

# %%
features_df["pickup_time_day"] = features_df["pickup_time"].dt.day
features_df["drop_time_day"] = features_df["drop_time"].dt.day

# %%
features_df["effective_time"] = features_df["duration"]-features_df["meter_waiting"]

# %%
features_df = features_df.drop(['duration'], axis = 1)
features_df = features_df.drop(['pickup_time'], axis = 1)
features_df = features_df.drop(['drop_time'], axis = 1)

# %%
features_df.head()
# Out:
#            additional_fare  meter_waiting  meter_waiting_fare  \
# tripid
# 189123628             10.5           56.0              0.0000
# 189125358             10.5           47.0              0.0000
# 189125719             10.5           80.0              0.0000
# 189127273             10.5          271.0             15.6638
# 189128020              NaN            NaN                 NaN
#
#            meter_waiting_till_pickup    fare  distance  pickup_time_hour  \
# tripid
# 189123628                       64.0  270.32  3.164501                 0
# 189125358                      134.0  197.85  1.968540                 0
# 189125719                       61.0  301.64  3.917991                 1
# 189127273                       68.0   82.30  0.535588                 2
# 189128020                        NaN  358.39  5.062797                 3
#
#            pickup_time_minute  drop_time_hour  drop_time_minute  \
# tripid
# 189123628                  20               0                34
# 189125358                  56               1                 9
# 189125719                   8               1                26
# 189127273                  27               2                37
# 189128020                  34               3                51
#
#            pickup_time_day  drop_time_day  effective_time
# tripid
# 189123628                1              1           778.0
# 189125358                1              1           744.0
# 189125719                1              1          1007.0
# 189127273                1              1           327.0
# 189128020                1              1             NaN

# %%
labels=joined_df.drop(['additional_fare'], axis = 1)
labels=labels.drop(['duration'], axis = 1)
labels=labels.drop(['meter_waiting'], axis = 1)
labels=labels.drop(['meter_waiting_fare'], axis = 1)
labels=labels.drop(['meter_waiting_till_pickup'], axis = 1)
labels=labels.drop(['pick_lat'], axis = 1)
labels=labels.drop(['pick_lon'], axis = 1)
labels=labels.drop(['drop_lat'], axis = 1)
labels=labels.drop(['drop_lon'], axis = 1)
labels=labels.drop(['fare'], axis = 1)
labels=labels.drop(['pickup_time'], axis = 1)
labels=labels.drop(['drop_time'], axis = 1)

# %%
labels.head()
# Out:
#            label
# tripid
# 189123628   True
# 189125358   True
# 189125719   True
# 189127273   True
# 189128020   True

# %%
numeric_features = ['additional_fare','meter_waiting', 'meter_waiting_fare', 'meter_waiting_till_pickup','fare','distance' ,'pickup_time_hour','pickup_time_minute','drop_time_hour','drop_time_minute', 'pickup_time_day','drop_time_day','effective_time']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features)])

# %%
RANDOM_SEED=0
X_train, X_eval, y_train, y_eval = train_test_split(
    features_df,
    labels,
    test_size=0.3,
    shuffle=True,
    stratify=labels,
    random_state=RANDOM_SEED
)

# %%
X_train.head()
# Out:
#            additional_fare  meter_waiting  meter_waiting_fare  \
# tripid
# 201666125             10.5          150.0              8.6700
# 191960496             10.5          165.0              9.6195
# 195867417             10.5          169.0              9.7682
# 196298365             40.5          339.0              0.0000
# 207320819             10.5          341.0             19.8803
#
#            meter_waiting_till_pickup    fare  distance  pickup_time_hour  \
# tripid
# 201666125                       47.0  106.97  1.088325                13
# 191960496                       78.0  161.11  0.112979                16
# 195867417                       74.0  185.31  1.154363                 9
# 196298365                       27.0  276.02  2.544655                19
# 207320819                       85.0  173.50  0.013009                11
#
#            pickup_time_minute  drop_time_hour  drop_time_minute  \
# tripid
# 201666125                  23              13                33
# 191960496                  47              16                59
# 195867417                   1               9                17
# 196298365                  12              19                38
# 207320819                  18              11                33
#
#            pickup_time_day  drop_time_day  effective_time
# tripid
# 201666125               18             18           434.0
# 191960496               14             14           571.0
# 195867417               29             29           795.0
# 196298365               29             29          1247.0
# 207320819                6              6           574.0

# %%
clf = Pipeline(steps=[('preprocessor', preprocessor),
                      ('classifier', svm.SVC())])

# %%
clf.fit(X_train, y_train)
print("model score: %.3f" % clf.score(X_train, y_train))
# Out:
# model score: 0.918

# %%
val_pred = clf.predict(X_eval)
val_pred
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
t=0.5
val_pred = val_pred > t
val_pred.astype(np.int)
y_pred=pd.DataFrame(val_pred)
y_pred
# Out:
#           0
# 0      True
# 1      True
# 2      True
# 3     False
# 4      True
# ...     ...
# 5148   True
# 5149   True
# 5150   True
# 5151   True
# 5152   True
#
# [5153 rows x 1 columns]

# %%
f1_score(y_eval, y_pred, average='micro')
# Out:
# 0.9153890937318068

# %%
test_df = pd.read_csv('test.csv' , index_col= 'tripid')
test_df["distance"] =  distance(test_df["pick_lat"],test_df["pick_lon"],test_df["drop_lat"],test_df["drop_lon"])

# %%
test_df = test_df.drop(['pick_lat'], axis = 1)
test_df = test_df.drop(['drop_lat'], axis = 1)
test_df = test_df.drop(['pick_lon'], axis = 1)
test_df = test_df.drop(['drop_lon'], axis = 1)

# %%
test_df["pickup_time"] = pd.to_datetime(test_df["pickup_time"],errors = "coerce")
test_df["drop_time"] = pd.to_datetime(test_df["drop_time"],errors = "coerce")
test_df["pickup_time_hour"] = test_df["pickup_time"].dt.hour
test_df["pickup_time_minute"] = test_df["pickup_time"].dt.minute
test_df["drop_time_hour"] =test_df["drop_time"].dt.hour
test_df["drop_time_minute"] =test_df["drop_time"].dt.minute
test_df["pickup_time_day"] = test_df["pickup_time"].dt.day
test_df["drop_time_day"] = test_df["drop_time"].dt.day
test_df["effective_time"] = test_df["duration"]-test_df["meter_waiting"]
test_df = test_df.drop(['duration'], axis = 1)
test_df = test_df.drop(['pickup_time'], axis = 1)
test_df = test_df.drop(['drop_time'], axis = 1)

# %%
test_df.head()
# Out:
#            additional_fare  meter_waiting  meter_waiting_fare  \
# tripid
# 213284604             10.5             42              2.4486
# 213286352             10.5             20              0.0000
# 213293973             10.5            255              2.6588
# 213294622             10.5             16              0.0000
# 213298687             10.5            392             12.3692
#
#            meter_waiting_till_pickup     fare   distance  pickup_time_hour  \
# tripid
# 213284604                        148   289.27   4.166730                 0
# 213286352                         91  1912.70  25.823263                 1
# 213293973                         23   394.00   3.676453                 5
# 213294622                        198   154.32   2.051619                 5
# 213298687                         69   147.47   1.608445                 7
#
#            pickup_time_minute  drop_time_hour  drop_time_minute  \
# tripid
# 213284604                  38               0                53
# 213286352                   2               2                13
# 213293973                   2               5                28
# 213294622                  30               5                38
# 213298687                   0               7                14
#
#            pickup_time_day  drop_time_day  effective_time
# tripid
# 213284604                1              1             882
# 213286352                1              1            4229
# 213293973                1              1            1297
# 213294622                1              1             446
# 213298687                1              1             422

# %%
test_probas = clf.predict(test_df)
result = test_probas > t
result.astype(np.int)
result
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
submission_df = pd.read_csv("sample_submission.csv", 
                            index_col="tripid")

# %%
np.testing.assert_array_equal(test_df.index.values, 
                              submission_df.index.values)

# %%
submission_df["prediction"] = result

# %%
submission_df.head()
# Out:
#            prediction
# tripid
# 213284604        True
# 213286352        True
# 213293973        True
# 213294622        True
# 213298687        True

# %%
submission_df.to_csv('results5.csv', index=True)
